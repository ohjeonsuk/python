# %%
import matplotlib.pyplot as plt

# plt.plot([X값 리스트], [Y값 리스트])

plt.plot([1, 2, 3, 4], [10, 50, 30, 100])

# %%
plt.plot([1,2,3,4])

# %%
plt.plot([1, 2, 3, 4], [10, 50, 30, 100])
plt.xlabel('x축 레이블', labelpad=10, loc='center')
plt.ylabel('y축 레이블', labelpad=10, loc='center')
# Out:
# Text(0, 0.5, 'y축 레이블')

# %%
plt.title('그래프 제목')

plt.plot([1,2,3,4],[10,50,30,100], label='코딩유치원')

plt.legend()

# %%
plt.plot([1,2,3,4],[10,50,30,100])

# [X최소값, X최대값, Y최소값, Y최대값]
plt.axis([1, 3, 10, 60])
# Out:
# (1.0, 3.0, 10.0, 60.0)
