# %%
import os
import json

# 디렉토리 경로 설정
x_train_path = 'drive/MyDrive/TS_Part2_Clickbait_Auto_EC'
y_train_path = 'drive/MyDrive/TL_Part2_Clickbait_Auto_EC'
x_test_path = 'drive/MyDrive/VS_Part2_Clickbait_Auto_EC'
y_test_path = 'drive/MyDrive/VL_Part2_Clickbait_Auto_EC'

x_train_path_direct = 'drive/MyDrive/TS_Part2_Clickbait_Direct_EC'
y_train_path_direct = 'drive/MyDrive/TL_Part2_Clickbait_Direct_EC'
x_test_path_direct = 'drive/MyDrive/VS_Part2_Clickbait_Direct_EC'
y_test_path_direct = 'drive/MyDrive/VL_Part2_Clickbait_Direct_EC'

x_train_path_nonclickbait = 'drive/MyDrive/TS_Part2_NonClickbait_Auto_EC'
y_train_path_nonclickbait = 'drive/MyDrive/TL_Part2_NonClickbait_Auto_EC'
x_test_path_nonclickbait = 'drive/MyDrive/VS_Part2_NonClickbait_Auto_EC'
y_test_path_nonclickbait = 'drive/MyDrive/VL_Part2_NonClickbait_Auto_EC'

# x_train과 y_train에서 모든 JSON 파일 찾기
x_train_files = [
    file_name for file_name in os.listdir(x_train_path) if file_name.endswith('.json')
]
y_train_files = [
    file_name for file_name in os.listdir(y_train_path) if file_name.endswith('.json')
]

# 추가 데이터 파일 찾기
x_train_files_direct = [
    file_name for file_name in os.listdir(x_train_path_direct) if file_name.endswith('.json')
]
y_train_files_direct = [
    file_name for file_name in os.listdir(y_train_path_direct) if file_name.endswith('.json')
]
x_train_files_nonclickbait = [
    file_name for file_name in os.listdir(x_train_path_nonclickbait) if file_name.endswith('.json')
]
y_train_files_nonclickbait = [
    file_name for file_name in os.listdir(y_train_path_nonclickbait) if file_name.endswith('.json')
]

# x_train과 y_train에서 모든 파일 로드
x_train_data = []
y_train_data = []

for file_name in x_train_files:
    x_data = json.load(open(os.path.join(x_train_path, file_name), 'r', encoding='utf-8'))
    y_data_file = file_name.replace(".json", "_L.json")
    if y_data_file in y_train_files:
        y_data = json.load(open(os.path.join(y_train_path, y_data_file), 'r', encoding='utf-8'))
        x_train_data.append(x_data)
        y_train_data.append(y_data['labeledDataInfo']['clickbaitClass'])

# 추가 데이터 로드
for file_name in x_train_files_direct:
    x_data = json.load(open(os.path.join(x_train_path_direct, file_name), 'r', encoding='utf-8'))
    y_data_file = file_name.replace(".json", "_L.json")
    if y_data_file in y_train_files_direct:
        y_data = json.load(open(os.path.join(y_train_path_direct, y_data_file), 'r', encoding='utf-8'))
        x_train_data.append(x_data)
        y_train_data.append(y_data['labeledDataInfo']['clickbaitClass'])

for file_name in x_train_files_nonclickbait:
    x_data = json.load(open(os.path.join(x_train_path_nonclickbait, file_name), 'r', encoding='utf-8'))
    y_data_file = file_name.replace(".json", "_L.json")
    if y_data_file in y_train_files_nonclickbait:
        y_data = json.load(open(os.path.join(y_train_path_nonclickbait, y_data_file), 'r', encoding='utf-8'))
        x_train_data.append(x_data)
        y_train_data.append(y_data['labeledDataInfo']['clickbaitClass'])

# x_test와 y_test에서 모든 JSON 파일 찾기
x_test_files = [
    file_name for file_name in os.listdir(x_test_path) if file_name.endswith('.json')
]
y_test_files = [
    file_name for file_name in os.listdir(y_test_path) if file_name.endswith('.json')
]

# 추가 데이터 파일 찾기
x_test_files_direct = [
    file_name for file_name in os.listdir(x_test_path_direct) if file_name.endswith('.json')
]
y_test_files_direct = [
    file_name for file_name in os.listdir(y_test_path_direct) if file_name.endswith('.json')
]
x_test_files_nonclickbait = [
    file_name for file_name in os.listdir(x_test_path_nonclickbait) if file_name.endswith('.json')
]
y_test_files_nonclickbait = [
    file_name for file_name in os.listdir(y_test_path_nonclickbait) if file_name.endswith('.json')
]

# x_test와 y_test에서 모든 파일 로드
x_test_data = []
y_test_data = []

for file_name in x_test_files:
    x_data = json.load(open(os.path.join(x_test_path, file_name), 'r', encoding='utf-8'))
    y_data_file = file_name.replace(".json", "_L.json")
    if y_data_file in y_test_files:
        y_data = json.load(open(os.path.join(y_test_path, y_data_file), 'r', encoding='utf-8'))
        x_test_data.append(x_data)
        y_test_data.append(y_data['labeledDataInfo']['clickbaitClass'])

# 추가 데이터 로드
for file_name in x_test_files_direct:
    x_data = json.load(open(os.path.join(x_test_path_direct, file_name), 'r', encoding='utf-8'))
    y_data_file = file_name.replace(".json", "_L.json")
    if y_data_file in y_test_files_direct:
        y_data = json.load(open(os.path.join(y_test_path_direct, y_data_file), 'r', encoding='utf-8'))
        x_test_data.append(x_data)
        y_test_data.append(y_data['labeledDataInfo']['clickbaitClass'])

for file_name in x_test_files_nonclickbait:
    x_data = json.load(open(os.path.join(x_test_path_nonclickbait, file_name), 'r', encoding='utf-8'))
    y_data_file = file_name.replace(".json", "_L.json")
    if y_data_file in y_test_files_nonclickbait:
        y_data = json.load(open(os.path.join(y_test_path_nonclickbait, y_data_file), 'r', encoding='utf-8'))
        x_test_data.append(x_data)
        y_test_data.append(y_data['labeledDataInfo']['clickbaitClass'])

# x_train과 y_train 데이터 확인
print(len(x_train_data), len(y_train_data))

# x_test와 y_test 데이터 확인
print(len(x_test_data), len(y_test_data))
# Out:
# 15711 15711
# 3610 3610

# %%
import os
import json
import torch
from transformers import BertTokenizer, BertForSequenceClassification
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %%
# 데이터를 토큰화하고 전처리하는 함수
def tokenize_and_preprocess(data, tokenizer, max_length):
    tokens = tokenizer.encode_plus(
        data['sourceDataInfo']['newsContent'],
        max_length=max_length,
        padding='max_length',
        truncation=True,
        return_tensors='pt',
    )
    return tokens

# %%
class CustomDataset(Dataset):
    def __init__(self, x_data, y_data, tokenizer, max_length):
        self.x_data = x_data
        self.y_data = y_data
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.x_data)

    def __getitem__(self, idx):
        data = self.x_data[idx]
        tokens = self.tokenizer.encode_plus(
            data['sourceDataInfo']['newsContent'],
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_tensors='pt',
        )
        labels = torch.tensor(self.y_data[idx], dtype=torch.long)
        return {'input_ids': tokens['input_ids'].squeeze(),
                'attention_mask': tokens['attention_mask'].squeeze(),
                'labels': labels}

# %%
# 토크나이저 및 모델
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)  # 2개 클래스(클릭베이트 또는 아님)를 가정
# Out:
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# 데이터 토큰화 및 전처리
max_length = 128  # 데이터 및 모델 요구에 따라 조절 가능

# %%
# 데이터셋 생성
train_dataset = CustomDataset(x_train_data, y_train_data, tokenizer, max_length)
test_dataset = CustomDataset(x_test_data, y_test_data, tokenizer, max_length)

# %%
# DataLoader
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

# %%
# 훈련 루프
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)
num_epochs = 10

# %%
for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for batch in tqdm(train_loader, desc=f'Epoch {epoch + 1}/{num_epochs}'):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)
        optimizer.zero_grad()
        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        total_loss += loss.item()
        loss.backward()
        optimizer.step()

    average_loss = total_loss / len(train_loader)
    print(f'Epoch {epoch + 1}/{num_epochs}, Loss: {average_loss}')
# Out:
# Epoch 1/10: 100%|██████████| 1964/1964 [06:41<00:00,  4.89it/s]
# Epoch 1/10, Loss: 0.4886173852501236
# Epoch 2/10: 100%|██████████| 1964/1964 [06:39<00:00,  4.91it/s]
# Epoch 2/10, Loss: 0.48655904094686697
# Epoch 3/10: 100%|██████████| 1964/1964 [06:41<00:00,  4.89it/s]
# Epoch 3/10, Loss: 0.486914652906161
# Epoch 4/10: 100%|██████████| 1964/1964 [06:40<00:00,  4.91it/s]
# Epoch 4/10, Loss: 0.4861468717668304
# Epoch 5/10: 100%|██████████| 1964/1964 [06:40<00:00,  4.90it/s]
# Epoch 5/10, Loss: 0.48575543194948534
# Epoch 6/10: 100%|██████████| 1964/1964 [06:39<00:00,  4.91it/s]
# Epoch 6/10, Loss: 0.48584597211050407
# Epoch 7/10: 100%|██████████| 1964/1964 [06:39<00:00,  4.92it/s]
# Epoch 7/10, Loss: 0.485054403680041
# Epoch 8/10: 100%|██████████| 1964/1964 [06:40<00:00,  4.90it/s]
# Epoch 8/10, Loss: 0.48531942587732785
# Epoch 9/10: 100%|██████████| 1964/1964 [06:40<00:00,  4.91it/s]
# Epoch 9/10, Loss: 0.48454021808146946
# ...

# %%
# 모델 저장
model_save_path = 'drive/MyDrive/all_10_bert_clickbait_model.pth'
torch.save(model.state_dict(), model_save_path)
print(f'Model saved to {model_save_path}')
# Out:
# Model saved to drive/MyDrive/all_10_bert_clickbait_model.pth

# %%
model.eval()
correct = 0
total = 0

with torch.no_grad():
    for batch in tqdm(test_loader, desc='Testing'):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)
        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        _, predicted = torch.max(outputs.logits, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = correct / total
print(f'Test Accuracy: {accuracy * 100:.2f}%')
# Out:
# Testing: 100%|██████████| 452/452 [01:00<00:00,  7.46it/s]
# Test Accuracy: 53.71%
