# %%
pip install bar_chart_race
# Out:
# Requirement already satisfied: bar_chart_race in c:\users\usn14\appdata\local\programs\python\python39\lib\site-packages (0.1.0)
# Requirement already satisfied: pandas>=0.24 in c:\users\usn14\appdata\local\programs\python\python39\lib\site-packages (from bar_chart_race) (1.4.0)
# Requirement already satisfied: matplotlib>=3.1 in c:\users\usn14\appdata\local\programs\python\python39\lib\site-packages (from bar_chart_race) (3.5.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\usn14\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.1->bar_chart_race) (4.29.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\usn14\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.1->bar_chart_race) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\usn14\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.1->bar_chart_race) (9.0.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\usn14\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.1->bar_chart_race) (1.22.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\usn14\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.1->bar_chart_race) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\usn14\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.1->bar_chart_race) (21.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\usn14\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.1->bar_chart_race) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\usn14\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.1->bar_chart_race) (1.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usn14\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.24->bar_chart_race) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\usn14\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1->bar_chart_race) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 22.1.1 is available.
# You should consider upgrading via the 'C:\Users\usn14\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

import numpy as np

import bar_chart_race as bcr

# %%
# csv 파일을 pandas 패키지를 이용해서 불러옴
df = pd.read_csv('premierLeague_tables_1992-2017.csv')

# 데이터 구성 파악
df.head()
# Out:
#     season               team  points   w   d   l   gf  ga  gd  pld  ...  d_h  \
# 0  2017-18    Manchester City     100  32   4   2  106  27  79   38  ...    2
# 1  2017-18  Manchester United      81  25   6   7   68  28  40   38  ...    2
# 2  2017-18  Tottenham Hotspur      77  23   8   7   74  36  38   38  ...    4
# 3  2017-18          Liverpool      75  21  12   5   84  38  46   38  ...    7
# 4  2017-18            Chelsea      70  21   7  10   62  38  24   38  ...    4
#
#    d_a  l_h  l_a  gf_h  gf_a  ga_h  ga_a  gd_h  gd_a
# 0    2    1    1    61    45    14    13    47    32
# 1    4    2    5    38    30     9    19    29    11
# 2    4    2    5    40    34    16    20    24    14
# 3    5    0    5    45    39    10    28    35    11
# 4    3    4    6    30    32    16    22    14    10
#
# [5 rows x 26 columns]

# %%
# 3가지 컬럼만 남기고 모두 제거
df = df[['season', 'team', 'points']]

# 확인
df.head()
# Out:
#     season               team  points
# 0  2017-18    Manchester City     100
# 1  2017-18  Manchester United      81
# 2  2017-18  Tottenham Hotspur      77
# 3  2017-18          Liverpool      75
# 4  2017-18            Chelsea      70

# %%
# 행은 'season', 열은 'team', 데이터는 points로 데이터 프레임 변경
df = df.pivot_table(values = 'points', index = 'season', columns = 'team')

# 확인
df.head()
# Out:
# team     Arsenal  Aston Villa  Barnsley  Birmingham City  Blackburn Rovers  \
# season
# 1992-93     56.0         74.0       NaN              NaN              71.0
# 1993-94     71.0         57.0       NaN              NaN              84.0
# 1994-95     51.0         48.0       NaN              NaN              89.0
# 1995-96     63.0         63.0       NaN              NaN              61.0
# 1996-97     68.0         61.0       NaN              NaN              42.0
#
# team     Blackpool  Bolton Wanderers  Bournemouth  Bradford City  \
# season
# 1992-93        NaN               NaN          NaN            NaN
# 1993-94        NaN               NaN          NaN            NaN
# 1994-95        NaN               NaN          NaN            NaN
# 1995-96        NaN              29.0          NaN            NaN
# 1996-97        NaN               NaN          NaN            NaN
#
# team     Brighton and Hove Albion  ...  Sunderland  Swansea City  \
# season                             ...
# 1992-93                       NaN  ...         NaN           NaN
# 1993-94                       NaN  ...         NaN           NaN
# 1994-95                       NaN  ...         NaN           NaN
# 1995-96                       NaN  ...         NaN           NaN
# 1996-97                       NaN  ...        40.0           NaN
#
# team     Swindon Town  Tottenham Hotspur  Watford  West Bromwich Albion  \
# season
# 1992-93           NaN               59.0      NaN                   NaN
# 1993-94          30.0               45.0      NaN                   NaN
# 1994-95           NaN               62.0      NaN                   NaN
# 1995-96           NaN               61.0      NaN                   NaN
# 1996-97           NaN               46.0      NaN                   NaN
#
# team     West Ham United  Wigan Athletic  Wimbledon FC  \
# season
# 1992-93              NaN             NaN          54.0
# 1993-94             52.0             NaN          65.0
# 1994-95             50.0             NaN          56.0
# 1995-96             51.0             NaN          41.0
# 1996-97             42.0             NaN          56.0
#
# team     Wolverhampton Wanderers
# season
# 1992-93                      NaN
# 1993-94                      NaN
# 1994-95                      NaN
# 1995-96                      NaN
# 1996-97                      NaN
#
# [5 rows x 49 columns]

# %%
# NaN 값을 0으로 채워주기
df = df.fillna(0)

# 확인
df.head()
# Out:
# team     Arsenal  Aston Villa  Barnsley  Birmingham City  Blackburn Rovers  \
# season
# 1992-93     56.0         74.0       0.0              0.0              71.0
# 1993-94     71.0         57.0       0.0              0.0              84.0
# 1994-95     51.0         48.0       0.0              0.0              89.0
# 1995-96     63.0         63.0       0.0              0.0              61.0
# 1996-97     68.0         61.0       0.0              0.0              42.0
#
# team     Blackpool  Bolton Wanderers  Bournemouth  Bradford City  \
# season
# 1992-93        0.0               0.0          0.0            0.0
# 1993-94        0.0               0.0          0.0            0.0
# 1994-95        0.0               0.0          0.0            0.0
# 1995-96        0.0              29.0          0.0            0.0
# 1996-97        0.0               0.0          0.0            0.0
#
# team     Brighton and Hove Albion  ...  Sunderland  Swansea City  \
# season                             ...
# 1992-93                       0.0  ...         0.0           0.0
# 1993-94                       0.0  ...         0.0           0.0
# 1994-95                       0.0  ...         0.0           0.0
# 1995-96                       0.0  ...         0.0           0.0
# 1996-97                       0.0  ...        40.0           0.0
#
# team     Swindon Town  Tottenham Hotspur  Watford  West Bromwich Albion  \
# season
# 1992-93           0.0               59.0      0.0                   0.0
# 1993-94          30.0               45.0      0.0                   0.0
# 1994-95           0.0               62.0      0.0                   0.0
# 1995-96           0.0               61.0      0.0                   0.0
# 1996-97           0.0               46.0      0.0                   0.0
#
# team     West Ham United  Wigan Athletic  Wimbledon FC  \
# season
# 1992-93              0.0             0.0          54.0
# 1993-94             52.0             0.0          65.0
# 1994-95             50.0             0.0          56.0
# 1995-96             51.0             0.0          41.0
# 1996-97             42.0             0.0          56.0
#
# team     Wolverhampton Wanderers
# season
# 1992-93                      0.0
# 1993-94                      0.0
# 1994-95                      0.0
# 1995-96                      0.0
# 1996-97                      0.0
#
# [5 rows x 49 columns]

# %%
df.iloc[:] = df.iloc[:].cumsum()
df.head()
# Out:
# team     Arsenal  Aston Villa  Barnsley  Birmingham City  Blackburn Rovers  \
# season
# 1992-93     56.0         74.0       0.0              0.0              71.0
# 1993-94    127.0        131.0       0.0              0.0             155.0
# 1994-95    178.0        179.0       0.0              0.0             244.0
# 1995-96    241.0        242.0       0.0              0.0             305.0
# 1996-97    309.0        303.0       0.0              0.0             347.0
#
# team     Blackpool  Bolton Wanderers  Bournemouth  Bradford City  \
# season
# 1992-93        0.0               0.0          0.0            0.0
# 1993-94        0.0               0.0          0.0            0.0
# 1994-95        0.0               0.0          0.0            0.0
# 1995-96        0.0              29.0          0.0            0.0
# 1996-97        0.0              29.0          0.0            0.0
#
# team     Brighton and Hove Albion  ...  Sunderland  Swansea City  \
# season                             ...
# 1992-93                       0.0  ...         0.0           0.0
# 1993-94                       0.0  ...         0.0           0.0
# 1994-95                       0.0  ...         0.0           0.0
# 1995-96                       0.0  ...         0.0           0.0
# 1996-97                       0.0  ...        40.0           0.0
#
# team     Swindon Town  Tottenham Hotspur  Watford  West Bromwich Albion  \
# season
# 1992-93           0.0               59.0      0.0                   0.0
# 1993-94          30.0              104.0      0.0                   0.0
# 1994-95          30.0              166.0      0.0                   0.0
# 1995-96          30.0              227.0      0.0                   0.0
# 1996-97          30.0              273.0      0.0                   0.0
#
# team     West Ham United  Wigan Athletic  Wimbledon FC  \
# season
# 1992-93              0.0             0.0          54.0
# 1993-94             52.0             0.0         119.0
# 1994-95            102.0             0.0         175.0
# 1995-96            153.0             0.0         216.0
# 1996-97            195.0             0.0         272.0
#
# team     Wolverhampton Wanderers
# season
# 1992-93                      0.0
# 1993-94                      0.0
# 1994-95                      0.0
# 1995-96                      0.0
# 1996-97                      0.0
#
# [5 rows x 49 columns]

# %%
bcr.bar_chart_race(df = df, 
                   n_bars = 10,
                   figsize=(6, 4),
                   sort='desc',
                   title='Premier League Clubs Points Since 1992')
# Out:
# C:\Users\usn14\AppData\Local\Programs\Python\Python39\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# C:\Users\usn14\AppData\Local\Programs\Python\Python39\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# C:\Users\usn14\AppData\Local\Programs\Python\Python39\lib\site-packages\bar_chart_race\_make_chart.py:226: UserWarning: Some of your columns never make an appearance in the animation. To reduce color repetition, set `filter_column_colors` to `True`
#   warnings.warn("Some of your columns never make an appearance in the animation. "
# <video width="1038" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...
